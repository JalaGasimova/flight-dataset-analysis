# %% [markdown]
# **<center><font size="5">FLIGHT DATASET ANALYSIS</center>**

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# **1. DATA COLLECTİON**

# %%
df=pd.read_csv(r'C:\Users\DELL\Documents\flight_data.csv')

# %% [markdown]
# **2. EXPLORATORY DATA ANALYSIS (EDA)**

# %% [markdown]
# *1.First view/initial inspection*

# %%
df.head(10)
# Out:
#   from_airport_code from_country dest_airport_code dest_country  \
# 0               ALG      Algeria               AEP    Argentina
# 1               ALG      Algeria               AEP    Argentina
# 2               ALG      Algeria               AEP    Argentina
# 3               ALG      Algeria               AEP    Argentina
# 4               ALG      Algeria               AEP    Argentina
# 5               ALG      Algeria               AEP    Argentina
# 6               ALG      Algeria               AEP    Argentina
# 7               ALG      Algeria               AEP    Argentina
# 8               ALG      Algeria               AEP    Argentina
# 9               ALG      Algeria               AEP    Argentina
#
#                                        aircraft_type airline_number  \
# 0  Airbus A318|Canadair RJ 1000|Airbus A330|Airbu...          multi
# 1  Airbus A318|Canadair RJ 1000|Boeing 787|Airbus...          multi
# ...

# %%
df.dtypes
# Out:
# from_airport_code     object
# from_country          object
# dest_airport_code     object
# dest_country          object
# aircraft_type         object
# airline_number        object
# airline_name          object
# flight_number         object
# departure_time        object
# arrival_time          object
# duration               int64
# stops                  int64
# price                float64
# currency              object
# scan_date             object
# dtype: object

# %%
df.describe()
# Out:
#             duration          stops          price
# count  998866.000000  998866.000000  997513.000000
# mean     1468.213762       1.654926    1763.370116
# std       705.799677       0.652485    1985.988209
# min        55.000000       0.000000       9.000000
# 25%       973.000000       1.000000     621.000000
# 50%      1410.000000       2.000000    1189.000000
# 75%      1880.000000       2.000000    2127.000000
# max      6095.000000       6.000000   33750.000000

# %%
df.columns
# Out:
# Index(['from_airport_code', 'from_country', 'dest_airport_code',
#        'dest_country', 'aircraft_type', 'airline_number', 'airline_name',
#        'flight_number', 'departure_time', 'arrival_time', 'duration', 'stops',
#        'price', 'currency', 'scan_date'],
#       dtype='object')

# %%
df['from_airport_code'].unique()
# Out:
# array(['ALG', 'AEP', 'SYD', 'MEL', 'VIE', 'BRU', 'GRU', 'CNF', 'VCP',
#        'YYZ', 'SCL', 'CAN', 'CTU', 'SZX', 'PEK', 'SHA', 'XIY', 'PVG',
#        'HGH', 'CGO', 'BOG', 'CPH', 'DUB', 'CAI', 'ADD', 'CDG', 'FRA',
#        'MUC', 'ATH', 'DEL', 'BOM'], dtype=object)

# %%
df['dest_country'].unique()
# Out:
# array(['Argentina', 'Australia', 'Austria', 'Brazil', 'Belgium', 'Canada',
#        'Chile', 'China', 'Columbia', 'Denmark', 'Dublin', 'Ethiopia',
#        'Egypt', 'France', 'Germany', 'India', 'Greece', 'Indonesia',
#        'Italy', 'Japan', 'Kenya', 'Mexico', 'Malaysia', 'Morocco',
#        'Norway', 'Netherlands', 'Panama', 'Philippines', 'Peru',
#        'Portugal', 'Rome', 'Qatar', 'Russia', 'Singapore', 'South Africa',
#        'South Korea', 'Spain', 'Taiwan', 'Sweden', 'Thailand', 'Turkey',
#        'United Arab Emirates', 'United Kingdom', 'United States',
#        'Zurich', 'Algeria', 'Vietnam'], dtype=object)

# %%
df['from_country'].unique()
# Out:
# array(['Algeria', 'Argentina', 'Australia', 'Austria', 'Belgium',
#        'Brazil', 'Canada', 'Chile', 'China', 'Columbia', 'Denmark',
#        'Dublin', 'Egypt', 'Ethiopia', 'France', 'Germany', 'Greece',
#        'India'], dtype=object)

# %%
df['airline_name'].unique()
# Out:
# array(['[Air France| Iberia| LATAM]', '[Air France| LATAM]',
#        '[Lufthansa| LATAM]', ..., '[SpiceJet| Air India]',
#        '[Air India| Thai Smile]', '[Air India| Scoot| Jetstar]'],
#       dtype=object)

# %%
df['dest_airport_code'].unique()
# Out:
# array(['AEP', 'SYD', 'MEL', 'VIE', 'GRU', 'BRU', 'YYZ', 'CNF', 'SCL',
#        'CAN', 'SZX', 'PVG', 'BOG', 'CPH', 'DUB', 'ADD', 'CAI', 'CDG',
#        'MUC', 'FRA', 'DEL', 'ATH', 'BOM', 'CGK', 'BLR', 'MXP', 'NRT',
#        'HND', 'NBO', 'MEX', 'KUL', 'CMN', 'OSL', 'AMS', 'PTY', 'MNL',
#        'LIM', 'LIS', 'FCO', 'DOH', 'SVO', 'SIN', 'DME', 'JNB', 'ICN',
#        'CPT', 'MAD', 'TPE', 'ARN', 'BKK', 'SAW', 'IST', 'DXB', 'LHR',
#        'LGW', 'MAN', 'ATL', 'ORD', 'LAX', 'PHX', 'MCO', 'CLT', 'MIA',
#        'IAH', 'SEA', 'FLL', 'SFO', 'JFK', 'ZRH', 'ALG', 'SGN', 'SHA',
#        'HGH', 'CTU', 'XIY', 'VCP', 'CGO', 'PEK'], dtype=object)

# %%
df['aircraft_type'].unique()
# Out:
# array(['Airbus A318|Canadair RJ 1000|Airbus A330|Airbus A320',
#        'Airbus A318|Canadair RJ 1000|Boeing 787|Airbus A320',
#        'Airbus A320|Airbus A321|Boeing 787|Airbus A320', ...,
#        'Airbus A321 (Sharklets)|Airbus A319|Airbus A319',
#        'Airbus A330|Airbus A320neo|Airbus A318',
#        'Airbus A321 (Sharklets)|Boeing 737MAX 8 Passenger|Airbus A320'],
#       dtype=object)

# %%
df['airline_number'].unique()
# Out:
# array(['multi', 'QR', 'EK', 'AF', 'TK', 'LH', 'TU', 'IB', 'TO', 'BA',
#        'AZ', 'VY', 'MS', 'AC', 'SV', '5O', 'HV', 'AH', 'AR', 'G3', 'LA',
#        'H2', 'JQ', 'VA', 'ZL', 'QF', 'FJ', 'EY', 'CI', 'NH', 'NZ', 'UA',
#        'DL', 'KE', 'PR', 'MF', 'TG', 'SQ', 'UL', 'JL', 'OZ', 'AI', 'CX',
#        'MH', 'TR', 'GA', 'SB', 'GK', 'HA', '5J', '3K', 'PX', 'QH', 'BI',
#        'OD', 'TP', 'KL', 'LX', 'ET', 'LO', 'OS', 'SN', 'A3', 'AY', 'EI',
#        'KM', 'EW', 'JU', 'BT', 'OU', 'FR', 'LG', 'DY', 'D8', 'RO', 'J9',
#        'W6', 'XY', 'SM', 'PC', 'DE', 'BR', 'UX', 'TS', 'FI', 'SK', '5F',
#        'U2', 'WB', 'AT', 'ME', '3O', 'TB', 'GQ', 'AD', 'AA', 'AV', 'AM',
#        'CM', 'DT', 'VH', 'OB', 'MU', 'WS', 'S4', 'RJ', 'PK', 'F8', 'WO',
#        'BW', 'JA', 'CZ', 'ZH', '3U', 'HU', 'FM', 'SC', 'LQ', 'KC', 'B7',
#        'NX', 'CA', 'TV', '9C', 'HO', 'JD', 'AQ', 'GJ', 'EU', 'Y8', 'DZ',
#        'RY', 'PN', 'P5', 'VV', 'NK', 'VB', 'B6', 'Y4', 'EC', 'RC', 'FS',
# ...

# %%
df['flight_number'].unique()
# Out:
# array(['AF1491|AF1491|AF1491|AF1491', 'AF1855|AF1855|AF1855|AF1855',
#        'LH1317|LH1317|LH1317', ..., 'G8322|G8322', 'G8345|G8345',
#        'SG712|SG712'], dtype=object)

# %%
df['departure_time'].unique()
# Out:
# array(['4/30/2022 14:30', '4/30/2022 12:45', '4/30/2022 12:35', ...,
#        '5/15/2022 2:55', '5/30/2022 2:55', '7/29/2022 2:55'], dtype=object)

# %%
df['arrival_time'].unique()
# Out:
# array(['5/1/2022 10:15', '5/1/2022 16:50', '5/2/2022 16:50', ...,
#        '8/29/2022 22:08', '5/1/2022 22:58', '5/9/2022 18:48'],
#       dtype=object)

# %%
df['duration'].unique()
# Out:
# array([1425, 1530, 1540, ..., 4371, 3776, 3753])

# %%
for val in df['price'].unique():
    print(val)
# Out:
# 1279.0
# 1284.0
# 1290.0
# 1347.0
# 1294.0
# 1313.0
# 1354.0
# 1363.0
# 1384.0
# 1386.0
# 1401.0
# 1727.0
# 1782.0
# 1803.0
# 2424.0
# 2439.0
# 2502.0
# 2503.0
# 2550.0
# 2551.0
# 2552.0
# 2557.0
# 2562.0
# 2671.0
# 2677.0
# 2693.0
# 2703.0
# 2714.0
# 2730.0
# 2956.0
# 3449.0
# 3496.0
# 3597.0
# 3696.0
# 3704.0
# 3782.0
# 3904.0
# 4346.0
# 4474.0
# 1124.0
# 1041.0
# 1382.0
# 1215.0
# 1647.0
# 1662.0
# 2062.0
# 2313.0
# 2297.0
# 1411.0
# 2311.0
# 1867.0
# 2430.0
# 1890.0
# 2492.0
# 2248.0
# 5641.0
# 2312.0
# 5655.0
# 2326.0
# 2333.0
# 5657.0
# 5671.0
# 5683.0
# 5685.0
# 5672.0
# 5736.0
# 5693.0
# 5737.0
# 5789.0
# 6056.0
# 8764.0
# 6989.0
# 8353.0
# 1034.0
# 1045.0
# 1227.0
# 1345.0
# 1370.0
# 1604.0
# 2080.0
# 2416.0
# 5887.0
# 7550.0
# 989.0
# 1140.0
# 1197.0
# 1070.0
# 1278.0
# 1286.0
# 1385.0
# 1617.0
# 1863.0
# 2105.0
# 2974.0
# 3294.0
# 3321.0
# 3622.0
# 3910.0
# 5292.0
# 6066.0
# 7007.0
# 7289.0
# 1360.0
# 1739.0
# 1877.0
# 1893.0
# 1932.0
# 1974.0
# 1977.0
# 1993.0
# 2061.0
# ...

# %%
df['currency'].unique()
# Out:
# array(['USD'], dtype=object)

# %%
df['stops'].unique()
# Out:
# array([3, 2, 1, 4, 0, 5, 6])

# %%
df['scan_date'].unique()
# Out:
# array(['4/29/2022 17:52'], dtype=object)

# %%
df.isnull().sum()
# Out:
# from_airport_code        0
# from_country             0
# dest_airport_code        0
# dest_country             0
# aircraft_type        13914
# airline_number           0
# airline_name             0
# flight_number            0
# departure_time           0
# arrival_time             0
# duration                 0
# stops                    0
# price                 1353
# currency                 0
# scan_date                0
# dtype: int64

# %%
df.shape
# Out:
# (998866, 15)

# %%
#dublikat sətir var mı yoxsa yox?
print(df.duplicated().any())
# Out:
# True

# %%
#hansı sətirlərin dublikat olduğunu görmək
print(df[df.duplicated()])
# Out:
#        from_airport_code from_country dest_airport_code dest_country  \
# 55                   ALG      Algeria               AEP    Argentina
# 68                   ALG      Algeria               AEP    Argentina
# 116                  ALG      Algeria               MEL    Australia
# 123                  ALG      Algeria               AEP    Argentina
# 124                  ALG      Algeria               AEP    Argentina
# ...                  ...          ...               ...          ...
# 998748               BOM        India               BKK     Thailand
# 998755               BOM        India               BKK     Thailand
# 998792               BOM        India               BKK     Thailand
# 998794               BOM        India               BKK     Thailand
# 998795               BOM        India               BKK     Thailand
#
#                                             aircraft_type airline_number  \
# ...

# %%
df.groupby('from_country')['airline_name'].agg(lambda x: x.mode()[0])
# Out:
# from_country
# Algeria                [Air France| Delta]
# Argentina                   [LATAM| Delta]
# Australia               [Qantas| American]
# Austria              [Austrian| Lufthansa]
# Belgium                        [Lufthansa]
# Brazil                             [LATAM]
# Canada                          [American]
# Chile                           [American]
# China                     [China Southern]
# Columbia                        [American]
# Denmark                        [Lufthansa]
# Dublin       [Aer Lingus| British Airways]
# Egypt                          [Lufthansa]
# Ethiopia            [Ethiopian| Lufthansa]
# France                         [Lufthansa]
# Germany                        [Lufthansa]
# Greece                         [Lufthansa]
# India                           [Emirates]
# Name: airline_name, dtype: object

# %% [markdown]
# *2. Univariate analysis*

# %%
numeric_cols=df.select_dtypes(include=['int64','float64']).columns
print(numeric_cols, "\n")
# Out:
# Index(['duration', 'stops', 'price'], dtype='object')

# %%
#duration sütununun paylanması
sns.histplot(df['duration'],kde=True)
plt.show()

# %%
#stops sütununun paylanması
sns.histplot(df['stops'],kde=True)
plt.show()

# %%
#Price sütununun paylanması
sns.histplot(df['price'],kde=True)
plt.show()

# %% [markdown]
# *3. Bivariate analysis*

# %%
#duration və price sütunları arasında əlaqə
sns.scatterplot(x='duration',y='price',data=df)
plt.title('Duration vs Price')
plt.xlabel('Duration (hours)')
plt.ylabel('Price')
plt.show()

# %%
#Stops və price sütunları arasında əlaqə
sns.scatterplot(x='stops',y='price', data=df)
plt.title("Stops vs Price")
plt.xlabel("Stops")
plt.ylabel("Price")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# Stops və duration sütunları arasında əlaqə
sns.scatterplot(x='stops',y='duration', data=df)
plt.title("Stops vs Duration")
plt.xlabel("Stops")
plt.ylabel("Duration")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# *3. Multivariate analysis*

# %%
#Korelyasiya cədvəli
corr = df.corr(numeric_only=True)

plt.figure(figsize=(12,8))
sns.heatmap(
    corr,
    annot=True,        # rəqəmləri yazır
    fmt=".2f",         # 2 onluq
    cmap="coolwarm",   # rəng skalası
    center=0,
    linewidths=0.5,    # xətlərin qalınlığı
    cbar_kws={"shrink": 0.8}  # rəng çubuğu kiçik olsun
)
plt.title("Correlation Matrix of All Numeric Features", fontsize=14)
plt.tight_layout()
plt.show()

# %% [markdown]
# *4. Outlierların aşkarlanması*

# %%
#boxplotla ümumi baxış
plt.figure(figsize=(8,5))
sns.boxplot(x=df['price'], color="skyblue")
plt.title("Price Distribution with Outliers")
plt.xlabel("Price (USD)")
plt.show()
print("\n")

# %%
#outlier dəyərlərin İQR-lə tapılması
col="price"
Q1= df[col].quantile(0.25)
Q3= df[col].quantile(0.75)
IQR= Q3-Q1
lower_bound= Q1-1.5*IQR
upper_bound= Q3+ 1.5*IQR

outliers=df[(df[col]<lower_bound) | (df[col]> upper_bound)][col]
print("Price sütunu üzrə Outlier dəyərlər")
print(outliers.tolist())
# Out:
# Price sütunu üzrə Outlier dəyərlər
# ...

# %% [markdown]
# **3. DATA CLEANING & PREPROCESSING**

# %% [markdown]
# Tarix tipində olmayan tarix sütunlarının(departure_time,arrival_time,scan_date) tipini dəyişməliyik

# %%
df['departure_time']=pd.to_datetime(df['departure_time'])
df['arrival_time']=pd.to_datetime(df['arrival_time'])
df['scan_date']=pd.to_datetime(df['scan_date'])
df.dtypes
# Out:
# from_airport_code            object
# from_country                 object
# dest_airport_code            object
# dest_country                 object
# aircraft_type                object
# airline_number               object
# airline_name                 object
# flight_number                object
# departure_time       datetime64[ns]
# arrival_time         datetime64[ns]
# duration                      int64
# stops                         int64
# price                       float64
# currency                     object
# scan_date            datetime64[ns]
# dtype: object

# %%
print("\n")

# %%
#dublikatları silməliyik
df=df.drop_duplicates()

# %%
# indi yenidən dublikat sətirlərin qalıb-qalmadığını yoxlayaq
print(df.duplicated().any())
# Out:
# False

# %%
print("\n")

# %% [markdown]
# *Null dəyərlərin əvəzlənməsi*

# %% [markdown]
# Datada null dəyərlərdən əlavə "unknown","not found","none" və s.yazılı dəyərlər də ola bilər. Ona görə biz hər ehtimala öncədən o dəyərləri null-la əvəz edib daha sonra,cleaning etməliyik.

# %%
fake_nulls=["none","unknown","not found","?","null","nan"]
df=df.replace(fake_nulls,np.nan)

# %%
#indi yenidən null dəyərlərin sayına baxırıq:
df.isnull().sum()
# Out:
# from_airport_code        0
# from_country             0
# dest_airport_code        0
# dest_country             0
# aircraft_type        13914
# airline_number           0
# airline_name             0
# flight_number            0
# departure_time           0
# arrival_time             0
# duration                 0
# stops                    0
# price                 1353
# currency                 0
# scan_date                0
# dtype: int64

# %% [markdown]
# _Əgər null dəyərlərin sayı ümumi dəyərlərin sayının 50%-dən çoxunu təşkil edirsə həmin sütunu silə bilərik_

# %%
#null dəyərlərin neçə faiz təşkil etdiyini yoxlayırıq
df.isnull().sum()/len(df)*100
# Out:
# from_airport_code    0.000000
# from_country         0.000000
# dest_airport_code    0.000000
# dest_country         0.000000
# aircraft_type        1.392980
# airline_number       0.000000
# airline_name         0.000000
# flight_number        0.000000
# departure_time       0.000000
# arrival_time         0.000000
# duration             0.000000
# stops                0.000000
# price                0.135454
# currency             0.000000
# scan_date            0.000000
# dtype: float64

# %% [markdown]
# İlk öncə aircraft_type sütunundaki null dəyərləri əvəz etməliyik. Ən doğru üsul ən çox təkrarlanan dəyərlə əvəz etməkdir. Ancaq daha dəqiq olması üçün qruplara görə ən çox təkrar olunan dəyərlə əvəz etməkdir

# %%
# İlk öncə hər bir uçulan ölkənin airportunda ən çox hansı təyyarə növü istifadə olunub ona baxırıq
df.groupby('from_airport_code')['aircraft_type'].agg(lambda x: x.mode()[0])
# Out:
# from_airport_code
# ADD                 Boeing 777|Boeing 777
# AEP    Airbus A320|Boeing 787|Airbus A320
# ALG               Airbus A320|Airbus A320
# ATH               Airbus A320|Airbus A320
# BOG                 Boeing 737|Boeing 737
# BOM               Airbus A320|Airbus A320
# BRU               Airbus A320|Airbus A320
# CAI                 Boeing 777|Boeing 777
# CAN                 Boeing 737|Boeing 737
# CDG               Airbus A320|Airbus A320
# CGO                 Boeing 737|Boeing 737
# CNF      Boeing 737|Boeing 737|Boeing 737
# CPH               Airbus A320|Airbus A320
# CTU    Airbus A320|Boeing 777|Airbus A320
# DEL               Airbus A320|Airbus A320
# DUB               Airbus A320|Airbus A320
# FRA               Airbus A320|Airbus A320
# GRU                 Boeing 777|Boeing 737
# HGH                 Boeing 737|Boeing 737
# MEL    Boeing 737|Airbus A330|Airbus A330
# MUC               Airbus A320|Airbus A320
# PEK    Airbus A330|Airbus A350|Boeing 737
# ...

# %%
#indi isə aircraft type sütunundaki null dəyərləri bu ən çox təkrarlanan dəyərlərlə əvəz edəcəyik
df["aircraft_type"] = df["aircraft_type"].fillna(
    df.groupby("from_airport_code")["aircraft_type"]
      .transform(lambda x: x.mode()[0])
)

# %%
df.isnull().sum()
# Out:
# from_airport_code       0
# from_country            0
# dest_airport_code       0
# dest_country            0
# aircraft_type           0
# airline_number          0
# airline_name            0
# flight_number           0
# departure_time          0
# arrival_time            0
# duration                0
# stops                   0
# price                1353
# currency                0
# scan_date               0
# dtype: int64

# %% [markdown]
# Eyni ilə price sütunundaki null dəyərləri də əvəz edəcəyik. Ancaq bu dəfə from_country və dest_country sütunlarına görə qruplaşdıracayıq. Price sütunu normal paylanmadığı üçün medianla əvəz etmək daha təhlükəsizdir.

# %%
df.groupby(["from_country","dest_country"])['price'].median()
# Out:
# from_country  dest_country
# Algeria       Argentina               2553.0
#               Australia               3109.0
#               Austria                  628.0
#               Belgium                  606.0
#               Brazil                  1687.0
#                                        ...
# India         United Arab Emirates     361.0
#               United Kingdom          1413.0
#               United States           1920.5
#               Vietnam                 1872.0
#               Zurich                  1392.0
# Name: price, Length: 833, dtype: float64

# %%
df["price"] = df["price"].fillna(
    df.groupby(["from_country","dest_country"])["price"].transform(lambda x: x.median())
)

# %%
print(df.isnull().sum())
print("\n")
# Out:
# from_airport_code    0
# from_country         0
# dest_airport_code    0
# dest_country         0
# aircraft_type        0
# airline_number       0
# airline_name         0
# flight_number        0
# departure_time       0
# arrival_time         0
# duration             0
# stops                0
# price                0
# currency             0
# scan_date            0
# dtype: int64

# %%
df['airline_name'].unique()
# Out:
# array(['[Air France| Iberia| LATAM]', '[Air France| LATAM]',
#        '[Lufthansa| LATAM]', ..., '[SpiceJet| Air India]',
#        '[Air India| Thai Smile]', '[Air India| Scoot| Jetstar]'],
#       dtype=object)

# %%
#Sütunda dəyərlər list şəklində [] içində yazılıb. Bu simvolları silməliyik
df['airline_name']=df['airline_name'].str.strip('[]')
df['airline_name'].unique()
# Out:
# array(['Air France| Iberia| LATAM', 'Air France| LATAM',
#        'Lufthansa| LATAM', ..., 'SpiceJet| Air India',
#        'Air India| Thai Smile', 'Air India| Scoot| Jetstar'], dtype=object)

# %% [markdown]
# **4. DATA TRANSFORMATION**

# %% [markdown]
# *Numeric dəyərlər arasındaki kolinearlığa baxırıq. Əgər vif dəyəri=1 olarsa,bu o deməkdir ki kolinearlıq yoxdur,vif= 1-5 arası olarsa, o deməkdir ki zəif/normal kolinearlıq var. Vif dəyəri >5 olması isə multikolinearlıq probleminin olmasını göstərir.*

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
from statsmodels.tools.tools import add_constant
x=df[['price','duration','stops']]
x=add_constant(x)
vif=pd.DataFrame()
vif['Variable']=x.columns
vif['VIF']=[variance_inflation_factor(x.values,i) for i in range(x.shape[1])]
print(vif)
for i,row in vif.iterrows():
    if row['Variable']=='const':
        continue
    elif row['VIF']<=1:
        print(f"{row['Variable']}: Kolinearlıq yoxdur")
    elif row['VIF']>1 and row['VIF']<5:
        print(f"{row['Variable']}: Normal kolinearlıq var")
    else:
        print(f"{row['Variable']}: Multikolinearlıq problemi var")
# Out:
#    Variable       VIF
# 0     const  8.020968
# 1     price  1.273008
# 2  duration  1.565580
# 3     stops  1.480375
# price: Normal kolinearlıq var
# duration: Normal kolinearlıq var
# stops: Normal kolinearlıq var

# %%
df.rename(columns={
    'departure_time':'departure_date',
    'arrival_time':'arrival_date'
},inplace=True)

# %%
df['departure_time']=df['departure_date'].dt.time
df['arrival_time']=df['arrival_date'].dt.time
df['departure_year']=df['departure_date'].dt.year
df['departure_month']=df['departure_date'].dt.strftime('%B')
df['arrival_year']=df['arrival_date'].dt.year
df['arrival_month']=df['arrival_date'].dt.strftime('%B')
df['scan_month']=df['scan_date'].dt.strftime('%B')

print(df.columns)
print("\n")
# Out:
# Index(['from_airport_code', 'from_country', 'dest_airport_code',
#        'dest_country', 'aircraft_type', 'airline_number', 'airline_name',
#        'flight_number', 'departure_date', 'arrival_date', 'duration', 'stops',
#        'price', 'currency', 'scan_date', 'departure_time', 'arrival_time',
#        'departure_year', 'departure_month', 'arrival_year', 'arrival_month',
#        'scan_month'],
#       dtype='object')

# %%
df['day_diff']=(df['departure_date']-df['scan_date']).dt.days

# %%
df['day_diff'].unique()
# Out:
# array([  0,   2,   6,  14,  29,  89, 119,   7,  15,  30, 120,  90,   1,
#          3,   4,  16, 121,  31,   8,  91])

# %%
df['departure_year'].unique()
df['departure_month'].unique()
# Out:
# array(['April', 'May', 'July', 'August'], dtype=object)

# %%
df['flight_route']=df['from_country'] + '->' + df['dest_country']

# %%
df['flight_route'].unique()
# Out:
# array(['Algeria->Argentina', 'Algeria->Australia', 'Algeria->Austria',
#        'Algeria->Brazil', 'Algeria->Belgium', 'Algeria->Canada',
#        'Algeria->Chile', 'Algeria->China', 'Algeria->Columbia',
#        'Algeria->Denmark', 'Algeria->Dublin', 'Algeria->Ethiopia',
#        'Algeria->Egypt', 'Algeria->France', 'Algeria->Germany',
#        'Algeria->India', 'Algeria->Greece', 'Algeria->Indonesia',
#        'Algeria->Italy', 'Algeria->Japan', 'Algeria->Kenya',
#        'Algeria->Mexico', 'Algeria->Malaysia', 'Algeria->Morocco',
#        'Algeria->Norway', 'Algeria->Netherlands', 'Algeria->Panama',
#        'Algeria->Philippines', 'Algeria->Peru', 'Algeria->Portugal',
#        'Algeria->Rome', 'Algeria->Qatar', 'Algeria->Russia',
#        'Algeria->Singapore', 'Algeria->South Africa',
#        'Algeria->South Korea', 'Algeria->Spain', 'Algeria->Taiwan',
#        'Algeria->Sweden', 'Algeria->Thailand', 'Algeria->Turkey',
# ...

# %% [markdown]
# **5.DATA VISUALIZATION**

# %%
df.head(40)
# Out:
#    from_airport_code from_country dest_airport_code dest_country  \
# 0                ALG      Algeria               AEP    Argentina
# 1                ALG      Algeria               AEP    Argentina
# 2                ALG      Algeria               AEP    Argentina
# 3                ALG      Algeria               AEP    Argentina
# 4                ALG      Algeria               AEP    Argentina
# 5                ALG      Algeria               AEP    Argentina
# 6                ALG      Algeria               AEP    Argentina
# 7                ALG      Algeria               AEP    Argentina
# 8                ALG      Algeria               AEP    Argentina
# 9                ALG      Algeria               AEP    Argentina
# 10               ALG      Algeria               AEP    Argentina
# 11               ALG      Algeria               AEP    Argentina
# 12               ALG      Algeria               AEP    Argentina
# ...

# %%
df.tail(20)
# Out:
#        from_airport_code from_country dest_airport_code dest_country  \
# 998846               BOM        India               SYD    Australia
# 998847               BOM        India               SYD    Australia
# 998848               BOM        India               SYD    Australia
# 998849               BOM        India               SYD    Australia
# 998850               BOM        India               SYD    Australia
# 998851               BOM        India               SYD    Australia
# 998852               BOM        India               SYD    Australia
# 998853               BOM        India               SYD    Australia
# 998854               BOM        India               SYD    Australia
# 998855               BOM        India               SYD    Australia
# 998856               BOM        India               SYD    Australia
# 998857               BOM        India               SYD    Australia
# 998858               BOM        India               SYD    Australia
# ...

# %%
df['departure_month'].unique()
print("\n")

# %% [markdown]
# Aylar üzrə uçuş sayları

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.countplot(data=df,x='departure_month')
plt.title("Count of flights by month")
plt.xlabel("Departure months")
plt.ylabel("Count of flights")
plt.show()

# %%
print("\n")

# %% [markdown]
# Həftənin günlərinə görə uçuçların paylanması

# %%
df['weekday'] = df['departure_date'].dt.day_name()

weekday_counts = df['weekday'].value_counts()

# Pie chart
plt.figure(figsize=(7,7))
plt.pie(weekday_counts, labels=weekday_counts.index, autopct='%1.1f%%',
        startangle=90, colors=plt.cm.Set3.colors)
plt.title("Flight Distribution by Weekday")
plt.show()
print("\n")

# %% [markdown]
# Eyni marşrut üzrə bilet qiymətlərinin həftənin günlərinə görə dəyişməsi

# %%
df['weekday'] = df['departure_date'].dt.day_name()

# Ən çox uçuş olunan 10 marşrut
top10_routes = df['flight_route'].value_counts().head(10).index
top10_data = df[df['flight_route'].isin(top10_routes)]

# Vizual
plt.figure(figsize=(12,7))
sns.lineplot(
    x='weekday', y='price', hue='flight_route',
    data=top10_data,
    estimator='mean',  # orta qiyməti göstərir
    errorbar=None      # səhv zolaqları çıxarır
)

plt.title("Average Ticket Price by Weekday (Top 10 Routes)")
plt.xlabel("Weekday")
plt.ylabel("Average Price (USD)")
plt.xticks(rotation=30, ha='right')
plt.legend(title="Flight Route", bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()
print("\n")

# %% [markdown]
# TOP10 ən çox səyahət olunan ölkə

# %%
top10=df['dest_country'].value_counts().head(10)
top10.plot(kind='bar',color='coral')
plt.title("TOP10 Most Visited Countries")
plt.xlabel("Country")
plt.ylabel("Count of flights")
plt.show()

# %% [markdown]
# Ən az səyahət olunan 10 ölkə

# %%
top10_least=df['dest_country'].value_counts().tail(10)
ax=top10_least.plot(kind='bar',color='coral')
plt.title("TOP10 Least Visited Countries")
plt.xlabel("Country")
plt.ylabel("Count of flights")
ax.bar_label(ax.containers[0],fmt='%.0f')
plt.show()
plt.tight_layout()
print("\n")

# %% [markdown]
# Aylara görə hər bir ölkəyə olunan uçuş sayı

# %%
top_countries = df['dest_country'].value_counts().head(10).index
df_top = df[df['dest_country'].isin(top_countries)]

month_country = df_top.groupby(['departure_month', 'dest_country']).size().reset_index(name='flight_count')

pivot_table = month_country.pivot(index='departure_month', columns='dest_country', values='flight_count').fillna(0)

plt.figure(figsize=(16,8))
sns.heatmap(pivot_table, annot=True, fmt='.0f', cmap='YlGnBu', linewidths=.5)
plt.title('Flights per Top 10 Countries by Month', fontsize=16)
plt.xlabel('Country')
plt.ylabel('Month')
plt.show()
print("\n")

# %% [markdown]
# TOP10 uçuş marşrutunun ortalama qiyməti

# %%
top10_route=df['flight_route'].value_counts().head(10)

ax=top10_route.plot(kind='bar',color='coral')
plt.title("Average Price of Top10 Flight Route")
plt.xlabel("Route")
plt.ylabel("Count of flights")
plt.xticks(rotation=30,ha='right')
ax.bar_label(ax.containers[0],fmt='%.0f')
plt.tight_layout()
plt.show()
print("\n")

# %% [markdown]
# Biletin sifariş edildiyi tarixlə uçuş tarixi arasındaki gün sayına görə qiymətin dəyişməsi(top5 uçuş marşrutuna görə)

# %%
df['day_diff'].max()
# Out:
# 121

# %%
top_routes = df['flight_route'].value_counts().head(5).index
df_top = df[df['flight_route'].isin(top_routes)]
plt.figure(figsize=(12,6))
sns.lineplot(data=df_top, x='day_diff', y='price', hue='flight_route', estimator='mean')

plt.title("Effect of Booking Lead Time on Price for Top 5 Routes")
plt.xlabel("Booking Lead Time (days)")
plt.ylabel("Average Price (USD)")
plt.legend(title="Route", bbox_to_anchor=(1.05,1), loc='upper left')
plt.xticks(range(0,121,10))
plt.tight_layout()
plt.show()
print("\n")

# %% [markdown]
# Top10 ən baha marşrut

# %%
route_avg_price = df.groupby('flight_route')['price'].mean().sort_values(ascending=False)

top10_expensive = route_avg_price.head(10)
import matplotlib.pyplot as plt

plt.figure(figsize=(12,6))
bars = plt.bar(top10_expensive.index, top10_expensive.values, color='coral')

plt.title("Top 10 Most Expensive Flight Routes")
plt.xlabel("Route")
plt.ylabel("Average Price (USD)")
plt.xticks(rotation=30, ha='right')

plt.bar_label(bars, fmt='%.0f')

plt.tight_layout()
plt.show()
print("\n")

# %% [markdown]
# TOP10 Ən ucuz marşrut

# %%
route_avg_price = df.groupby('flight_route')['price'].mean().sort_values(ascending=False)

top10_cheapest = route_avg_price.tail(10)
import matplotlib.pyplot as plt

plt.figure(figsize=(12,6))
bars = plt.bar(top10_cheapest.index, top10_cheapest.values, color='coral')

plt.title("Top 10 Cheapest Flight Routes")
plt.xlabel("Route")
plt.ylabel("Average Price (USD)")
plt.xticks(rotation=30, ha='right')

plt.bar_label(bars, fmt='%.0f')

plt.tight_layout()
plt.show()
print("\n")
